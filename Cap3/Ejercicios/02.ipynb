# %% [markdown]
# dibujar los retratos de fase e los sismtemas lineales

# %%
from sympy import *
#para poder graficar
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
import pylab as pl

# %% [markdown]
# a) dx/dt=0, dy/dt=x+2y

# %%
#puntos criticos
x,y=symbols('x,y')
P=0
Q=x+2*y
#establecer P(x,y)=0 y Q(x,y)=0
Peqn=Eq(P,0)
Qeqn=Eq(Q,0)
pcriticos=solve((Peqn,Qeqn),x,y)
print(pcriticos)
#eigenvalores y eigenvectores
M=Matrix([[0,0],[1,2]])
print(M.eigenvals())
pprint(M.eigenvects())
# Out:
# {x: -2*y}
# {0: 1, 2: 1}
# ⎡⎛      ⎡⎡-2⎤⎤⎞  ⎛      ⎡⎡0⎤⎤⎞⎤
# ⎢⎜0, 1, ⎢⎢  ⎥⎥⎟, ⎜2, 1, ⎢⎢ ⎥⎥⎟⎥
# ⎣⎝      ⎣⎣1 ⎦⎦⎠  ⎝      ⎣⎣1⎦⎦⎠⎦

# %% [markdown]
# Los eigenvalores son reales distintos positivos por lo que el punto critico (la rescta y=-x/2) es un nodo inestable

# %%
#sistema lineal
def dx_dt(x,t):
    return [0*x[0]+0*x[1],x[0]+2*x[1]]
#trayectorias en tiempo hacia adelante
ts=np.linspace(0,10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#trayectorias en tiempo hacia atras
ts=np.linspace(0,-10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#etiquetas de ejes y estilo de letra
plt.xlabel('x',fontsize=10)
plt.ylabel('y',fontsize=10)
plt.tick_params(labelsize=10)
plt.xlim(-3,3)
plt.ylim(-3,3)
#campo vectorial
X,Y=np.mgrid[-3:3:10j,-3:3:10j]
u=0*X+0*Y
v=X+2*Y
pl.quiver(X,Y,u,v,color='b')
plt.show()

# %% [markdown]
# b) dx/dt=x+2y, dy/dt=0

# %%
#puntos criticos
x,y=symbols('x,y')
P=x+2*y
Q=0
#establecer P(x,y)=0 y Q(x,y)=0
Peqn=Eq(P,0)
Qeqn=Eq(Q,0)
pcriticos=solve((Peqn,Qeqn),x,y)
print(pcriticos)
#eigenvalores y eigenvectores
M=Matrix([[1,2],[0,0]])
print(M.eigenvals())
pprint(M.eigenvects())
# Out:
# {x: -2*y}
# {1: 1, 0: 1}
# ⎡⎛      ⎡⎡-2⎤⎤⎞  ⎛      ⎡⎡1⎤⎤⎞⎤
# ⎢⎜0, 1, ⎢⎢  ⎥⎥⎟, ⎜1, 1, ⎢⎢ ⎥⎥⎟⎥
# ⎣⎝      ⎣⎣1 ⎦⎦⎠  ⎝      ⎣⎣0⎦⎦⎠⎦

# %% [markdown]
# Los eigenvalores son reales distintos positivos por lo que el punto critico (recta y=-x/2) es un nodo inestable

# %%
#sistema lineal
def dx_dt(x,t):
    return [x[0]+2*x[1],0*x[0]+0*x[1]]
#trayectorias en tiempo hacia adelante
ts=np.linspace(0,10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#trayectorias en tiempo hacia atras
ts=np.linspace(0,-10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#etiquetas de ejes y estilo de letra
plt.xlabel('x',fontsize=10)
plt.ylabel('y',fontsize=10)
plt.tick_params(labelsize=10)
plt.xlim(-3,3)
plt.ylim(-3,3)
#campo vectorial
X,Y=np.mgrid[-3:3:10j,-3:3:10j]
u=X+2*Y
v=0*X+0*Y
pl.quiver(X,Y,u,v,color='b')
plt.show()

# %% [markdown]
# c) dx/dt=3x+4y, dy/dt=4x-3y

# %%
#puntos criticos
x,y=symbols('x,y')
P=3*x+4*y
Q=4*x-3*y
#establecer P(x,y)=0 y Q(x,y)=0
Peqn=Eq(P,0)
Qeqn=Eq(Q,0)
pcriticos=solve((Peqn,Qeqn),x,y)
print(pcriticos)
#eigenvalores y eigenvectores
M=Matrix([[3,4],[4,-3]])
print(M.eigenvals())
pprint(M.eigenvects())
# Out:
# {y: 0, x: 0}
# {-5: 1, 5: 1}
# ⎡⎛       ⎡⎡-1/2⎤⎤⎞  ⎛      ⎡⎡2⎤⎤⎞⎤
# ⎢⎜-5, 1, ⎢⎢    ⎥⎥⎟, ⎜5, 1, ⎢⎢ ⎥⎥⎟⎥
# ⎣⎝       ⎣⎣ 1  ⎦⎦⎠  ⎝      ⎣⎣1⎦⎦⎠⎦

# %% [markdown]
# Los eigenvalores son un positivo y otro negativo entonces el punto critico (que esta en el origen) es un punto silla.

# %%
#sistema lineal
def dx_dt(x,t):
    return [3*x[0]+4*x[1],4*x[0]-3*x[1]]
#trayectorias en tiempo hacia adelante
ts=np.linspace(0,10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#trayectorias en tiempo hacia atras
ts=np.linspace(0,-10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#etiquetas de ejes y estilo de letra
plt.xlabel('x',fontsize=10)
plt.ylabel('y',fontsize=10)
plt.tick_params(labelsize=10)
plt.xlim(-3,3)
plt.ylim(-3,3)
#campo vectorial
#X,Y=np.mgrid[-3:3:10j,-3:3:10j]
#u=3*X+4*Y
#v=4*X-3*Y
#pl.quiver(X,Y,u,v,color='b')
plt.show()

# %% [markdown]
# d) dx/dt=3x+y, dy/dt=-x+3y

# %%
#puntos criticos
x,y=symbols('x,y')
P=3*x+y
Q=-1*x-3*y
#establecer P(x,y)=0 y Q(x,y)=0
Peqn=Eq(P,0)
Qeqn=Eq(Q,0)
pcriticos=solve((Peqn,Qeqn),x,y)
print(pcriticos)
#eigenvalores y eigenvectores
M=Matrix([[3,1],[-1,3]])
print(M.eigenvals())
pprint(M.eigenvects())
# Out:
# {y: 0, x: 0}
# {3 - I: 1, 3 + I: 1}
# ⎡⎛          ⎡⎡ⅈ⎤⎤⎞  ⎛          ⎡⎡-ⅈ⎤⎤⎞⎤
# ⎢⎜3 - ⅈ, 1, ⎢⎢ ⎥⎥⎟, ⎜3 + ⅈ, 1, ⎢⎢  ⎥⎥⎟⎥
# ⎣⎝          ⎣⎣1⎦⎦⎠  ⎝          ⎣⎣1 ⎦⎦⎠⎦

# %% [markdown]
# Los eigenvalores son complejos y alfa>0, por lo que el punto critico (el origen) es un foco inestable

# %%
#sistema lineal
def dx_dt(x,t):
    return [3*x[0]+x[1],-1*x[0]+3*x[1]]
#trayectorias en tiempo hacia adelante
ts=np.linspace(0,10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#trayectorias en tiempo hacia atras
ts=np.linspace(0,-10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#etiquetas de ejes y estilo de letra
plt.xlabel('x',fontsize=10)
plt.ylabel('y',fontsize=10)
plt.tick_params(labelsize=10)
plt.xlim(-3,3)
plt.ylim(-3,3)
#campo vectorial
X,Y=np.mgrid[-3:3:10j,-3:3:10j]
u=3*X+Y
v=-1*X+3*Y
pl.quiver(X,Y,u,v,color='b')
plt.show()

# %% [markdown]
# e) dx/dt=y, dy/dt=-x-2y

# %%
#puntos criticos
x,y=symbols('x,y')
P=y
Q=-1*x-2*y
#establecer P(x,y)=0 y Q(x,y)=0
Peqn=Eq(P,0)
Qeqn=Eq(Q,0)
pcriticos=solve((Peqn,Qeqn),x,y)
print(pcriticos)
#eigenvalores y eigenvectores
M=Matrix([[0,1],[-1,-2]])
print(M.eigenvals())
pprint(M.eigenvects())
# Out:
# {x: 0, y: 0}
# {-1: 2}
# ⎡⎛       ⎡⎡-1⎤⎤⎞⎤
# ⎢⎜-1, 2, ⎢⎢  ⎥⎥⎟⎥
# ⎣⎝       ⎣⎣1 ⎦⎦⎠⎦

# %% [markdown]
# Los eigenvalores son repetidos y un eigenvector por lo que el punto critico (el origen) es un nodo degenerado

# %%
#sistema lineal
def dx_dt(x,t):
    return [x[1],-1*x[0]-2*x[1]]
#trayectorias en tiempo hacia adelante
ts=np.linspace(0,10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#trayectorias en tiempo hacia atras
ts=np.linspace(0,-10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#etiquetas de ejes y estilo de letra
plt.xlabel('x',fontsize=10)
plt.ylabel('y',fontsize=10)
plt.tick_params(labelsize=10)
plt.xlim(-3,3)
plt.ylim(-3,3)
#campo vectorial
X,Y=np.mgrid[-3:3:10j,-3:3:10j]
u=Y
v=-1*X-2*Y
pl.quiver(X,Y,u,v,color='b')
plt.show()

# %% [markdown]
# f) dx/dt=x-y, dy/dt=y-x

# %%
#puntos criticos
x,y=symbols('x,y')
P=x-y
Q=-1*x+y
#establecer P(x,y)=0 y Q(x,y)=0
Peqn=Eq(P,0)
Qeqn=Eq(Q,0)
pcriticos=solve((Peqn,Qeqn),x,y)
print(pcriticos)
#eigenvalores y eigenvectores
M=Matrix([[1,-1],[-1,1]])
print(M.eigenvals())
pprint(M.eigenvects())
# Out:
# {x: y}
# {2: 1, 0: 1}
# ⎡⎛      ⎡⎡1⎤⎤⎞  ⎛      ⎡⎡-1⎤⎤⎞⎤
# ⎢⎜0, 1, ⎢⎢ ⎥⎥⎟, ⎜2, 1, ⎢⎢  ⎥⎥⎟⎥
# ⎣⎝      ⎣⎣1⎦⎦⎠  ⎝      ⎣⎣1 ⎦⎦⎠⎦

# %% [markdown]
# Los eigenvalores son reales distintos positivos, por lo que el punto critico (que son infinitos puntos en la linea x=y) es un nodo inestable

# %%
#sistema lineal
def dx_dt(x,t):
    return [x[0]-x[1],-1*x[0]+x[1]]
#trayectorias en tiempo hacia adelante
ts=np.linspace(0,10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#trayectorias en tiempo hacia atras
ts=np.linspace(0,-10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#etiquetas de ejes y estilo de letra
plt.xlabel('x',fontsize=10)
plt.ylabel('y',fontsize=10)
plt.tick_params(labelsize=10)
plt.xlim(-3,3)
plt.ylim(-3,3)
#campo vectorial
X,Y=np.mgrid[-3:3:10j,-3:3:10j]
u=X-Y
v=-1*X+Y
pl.quiver(X,Y,u,v,color='b')
plt.show()
