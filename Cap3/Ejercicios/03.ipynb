# %% [markdown]
# Oscilador mecanico d^2x/dt^2=+mudx/dt+25x=0

# %% [markdown]
# a) Reescribir la ecuacion como sistema de primer orden usando dx/dt=y

# %% [markdown]
# El sistema es: dx/dt=y , dy/dt=-mu*y-25x

# %% [markdown]
# b) dibujar retratos de fase cuando i)mu=-8 ii)mu=0 iii)mu=8 iv)mu=26

# %%
from sympy import *
#para poder graficar
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
import pylab as pl

# %% [markdown]
# i) mu=-8
# dx/dt=y , dy/dt=8*y-25x

# %%
#puntos criticos
x,y=symbols('x,y')
P=y
Q=-25*x+8*y
#establecer P(x,y)=0 y Q(x,y)=0
Peqn=Eq(P,0)
Qeqn=Eq(Q,0)
print(solve((Peqn,Qeqn),x,y))
#Eigenvalores y eigenvectores
M=Matrix([[0,1],[-25,8]])
print(M.eigenvals())
pprint(M.eigenvects())
# Out:
# {x: 0, y: 0}
# {4 - 3*I: 1, 4 + 3*I: 1}
# ⎡⎛            ⎡⎡4    3⋅ⅈ⎤⎤⎞  ⎛            ⎡⎡4    3⋅ⅈ⎤⎤⎞⎤
# ⎢⎜            ⎢⎢── + ───⎥⎥⎟  ⎜            ⎢⎢── - ───⎥⎥⎟⎥
# ⎢⎜4 - 3⋅ⅈ, 1, ⎢⎢25    25⎥⎥⎟, ⎜4 + 3⋅ⅈ, 1, ⎢⎢25    25⎥⎥⎟⎥
# ⎢⎜            ⎢⎢        ⎥⎥⎟  ⎜            ⎢⎢        ⎥⎥⎟⎥
# ⎣⎝            ⎣⎣   1    ⎦⎦⎠  ⎝            ⎣⎣   1    ⎦⎦⎠⎦

# %% [markdown]
# Los eigenvalores son complejos y alfa>0, por lo que el punto critico (0,0) es un foco inestable

# %%
#sistema lineal
def dx_dt(x,t):
    return [0*x[0]+x[1],-25*x[0]+8*x[1]]
#trayectorias en tiempo hacia adelante
ts=np.linspace(0,10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#trayectorias en tiempo hacia atras
ts=np.linspace(0,-10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#etiquetas de ejes y estilo de letra
plt.xlabel('x',fontsize=10)
plt.ylabel('y',fontsize=10)
plt.tick_params(labelsize=10)
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.show()

# %% [markdown]
# ii) mu=0
# dx/dt=y , dy/dt=-25x

# %%
#puntos criticos
x,y=symbols('x,y')
P=y
Q=-25*x
#establecer P(x,y)=0 y Q(x,y)=0
Peqn=Eq(P,0)
Qeqn=Eq(Q,0)
print(solve((Peqn,Qeqn),x,y))
#Eigenvalores y eigenvectores
M=Matrix([[0,1],[-25,0]])
print(M.eigenvals())
pprint(M.eigenvects())
# Out:
# {x: 0, y: 0}
# {-5*I: 1, 5*I: 1}
# ⎡⎛         ⎡⎡ⅈ⎤⎤⎞  ⎛        ⎡⎡-ⅈ ⎤⎤⎞⎤
# ⎢⎜         ⎢⎢─⎥⎥⎟  ⎜        ⎢⎢───⎥⎥⎟⎥
# ⎢⎜-5⋅ⅈ, 1, ⎢⎢5⎥⎥⎟, ⎜5⋅ⅈ, 1, ⎢⎢ 5 ⎥⎥⎟⎥
# ⎢⎜         ⎢⎢ ⎥⎥⎟  ⎜        ⎢⎢   ⎥⎥⎟⎥
# ⎣⎝         ⎣⎣1⎦⎦⎠  ⎝        ⎣⎣ 1 ⎦⎦⎠⎦

# %% [markdown]
# Los eigenvalores son complejos con alfa=0, por lo que el punto critico (0,0) es un centro.

# %%
#sistema lineal
def dx_dt(x,t):
    return [0*x[0]+x[1],-25*x[0]+0*x[1]]
#trayectorias en tiempo hacia adelante
ts=np.linspace(0,10,500)
ic=np.linspace(-4,4,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#trayectorias en tiempo hacia atras
ts=np.linspace(0,-10,500)
ic=np.linspace(-4,4,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#etiquetas de ejes y estilo de letra
plt.xlabel('x',fontsize=10)
plt.ylabel('y',fontsize=10)
plt.tick_params(labelsize=10)
plt.xlim(-4,4)
plt.ylim(-4,4)
plt.show()

# %% [markdown]
# iii) mu=8 dx/dt=y , dy/dt=-8*y-25x

# %%
#puntos criticos
x,y=symbols('x,y')
P=y
Q=-25*x-8*y
#establecer P(x,y)=0 y Q(x,y)=0
Peqn=Eq(P,0)
Qeqn=Eq(Q,0)
print(solve((Peqn,Qeqn),x,y))
#Eigenvalores y eigenvectores
M=Matrix([[0,1],[-25,-8]])
print(M.eigenvals())
pprint(M.eigenvects())
# Out:
# {x: 0, y: 0}
# {-4 - 3*I: 1, -4 + 3*I: 1}
# ⎡⎛             ⎡⎡  4    3⋅ⅈ⎤⎤⎞  ⎛             ⎡⎡  4    3⋅ⅈ⎤⎤⎞⎤
# ⎢⎜             ⎢⎢- ── + ───⎥⎥⎟  ⎜             ⎢⎢- ── - ───⎥⎥⎟⎥
# ⎢⎜-4 - 3⋅ⅈ, 1, ⎢⎢  25    25⎥⎥⎟, ⎜-4 + 3⋅ⅈ, 1, ⎢⎢  25    25⎥⎥⎟⎥
# ⎢⎜             ⎢⎢          ⎥⎥⎟  ⎜             ⎢⎢          ⎥⎥⎟⎥
# ⎣⎝             ⎣⎣    1     ⎦⎦⎠  ⎝             ⎣⎣    1     ⎦⎦⎠⎦

# %% [markdown]
# Los eigenvalores son complejos y alfa<0, por lo que el punto critico (0,0) es un foco estable.

# %%
#sistema lineal
def dx_dt(x,t):
    return [0*x[0]+x[1],-25*x[0]-8*x[1]]
#trayectorias en tiempo hacia adelante
ts=np.linspace(0,10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#trayectorias en tiempo hacia atras
ts=np.linspace(0,-10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#etiquetas de ejes y estilo de letra
plt.xlabel('x',fontsize=10)
plt.ylabel('y',fontsize=10)
plt.tick_params(labelsize=10)
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.show()

# %% [markdown]
# iv) mu=26 dx/dt=y , dy/dt=-26*y-25x

# %%
#puntos criticos
x,y=symbols('x,y')
P=y
Q=-25*x-26*y
#establecer P(x,y)=0 y Q(x,y)=0
Peqn=Eq(P,0)
Qeqn=Eq(Q,0)
print(solve((Peqn,Qeqn),x,y))
#Eigenvalores y eigenvectores
M=Matrix([[0,1],[-25,-26]])
print(M.eigenvals())
pprint(M.eigenvects())
# Out:
# {x: 0, y: 0}
# {-1: 1, -25: 1}
# ⎡⎛        ⎡⎡-1/25⎤⎤⎞  ⎛       ⎡⎡-1⎤⎤⎞⎤
# ⎢⎜-25, 1, ⎢⎢     ⎥⎥⎟, ⎜-1, 1, ⎢⎢  ⎥⎥⎟⎥
# ⎣⎝        ⎣⎣  1  ⎦⎦⎠  ⎝       ⎣⎣1 ⎦⎦⎠⎦

# %% [markdown]
# Los iegenvalores son reales negativos distintos por lo que el punto critico (0,0) es un nodo estable.

# %%
#sistema lineal
def dx_dt(x,t):
    return [0*x[0]+x[1],-25*x[0]-26*x[1]]
#trayectorias en tiempo hacia adelante
ts=np.linspace(0,10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#trayectorias en tiempo hacia atras
ts=np.linspace(0,-10,500)
ic=np.linspace(-3,3,6)
for r in ic:
    for s in ic:
        x0=[r,s]
        xs=odeint(dx_dt,x0,ts)
        plt.plot(xs[:,0],xs[:,1],"r-")
#etiquetas de ejes y estilo de letra
plt.xlabel('x',fontsize=10)
plt.ylabel('y',fontsize=10)
plt.tick_params(labelsize=10)
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.show()

# %% [markdown]
# c) Describir el comportamiento dinamico en cada caso dado que x(0)=1 y dx(0)/dt=0
